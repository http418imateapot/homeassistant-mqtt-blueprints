# %% [markdown]
# # Lab 03: Allowlist and Rejection Scenarios
# Use a Home Assistant test receiver configured as described in each scenario.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'examples').is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from examples.scripts.lab_common import BrokerConfig, run_notebook
config = BrokerConfig('127.0.0.1', 1883)
topic = 'homeassistant/commands'

# %% [markdown]
# ## Step 01: Build rejection scenarios
# **Purpose:** Prepare payloads for three receiver rejection paths.
# **Execution:** Build a disallowed domain, target-domain mismatch, and v1 payload for `v2_only`.
# **Expected result:** Each payload maps to a specific receiver validation rule.

# %%
from examples.scripts.lab03_allowlist_reject.step_01_build_scenarios import run as step_01
step_01()

# %% [markdown]
# ## Step 02: Publish and observe rejection
# **Purpose:** Send invalid scenarios and locate rejection evidence.
# **Execution:** Publish to the command topic, then inspect Home Assistant system logs.
# **Expected result:** Warnings appear only in HA logs; the blueprint publishes no ack or result topic.

# %%
from examples.scripts.lab03_allowlist_reject.step_02_publish_observe import run as step_02
run_notebook(lambda: step_02(config, topic))
