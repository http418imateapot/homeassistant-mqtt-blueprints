# %% [markdown]
# # Lab 02: Publish Schema v2 Commands
# Review the example entity IDs before publishing to a Home Assistant test instance.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'examples').is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from examples.scripts.lab_common import BrokerConfig, run_notebook
from examples.scripts.lab02_command_v2.step_01_build_validate import DEFAULT_ENTITIES
config = BrokerConfig('127.0.0.1', 1883)
topic = 'homeassistant/commands'
entities = DEFAULT_ENTITIES.copy()

# %% [markdown]
# ## Step 01: Build and validate v2 commands
# **Purpose:** Create one command for each writable blueprint domain.
# **Execution:** Build light, switch, climate, cover, fan, and lock envelopes.
# **Expected result:** `schema`, `service`, `target`, and `data` satisfy the receiver's structural rules.

# %%
from examples.scripts.lab02_command_v2.step_01_build_validate import run as step_01
step_01(entities)

# %% [markdown]
# ## Step 02: Publish v2 commands
# **Purpose:** Send all six envelopes to the command receiver.
# **Execution:** Publish JSON to `homeassistant/commands` with QoS 1.
# **Expected result:** Only commands passing schema, allowlist, target-domain, and area checks are dispatched.

# %%
from examples.scripts.lab02_command_v2.step_02_publish import run as step_02
run_notebook(lambda: step_02(config, topic, entities))
