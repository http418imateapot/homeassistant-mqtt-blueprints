# %% [markdown]
# # Lab 04: Inspect Retained Metadata
# Discovery config and capability metadata are emitted only on uploader heartbeat runs.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'examples').is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from examples.scripts.lab_common import BrokerConfig, run_notebook
config = BrokerConfig('127.0.0.1', 1883)
base_topic = 'homeassistant'
discovery_prefix = 'homeassistant'
seconds = 3.0

# %% [markdown]
# ## Step 01: Connect and identify retained topics
# **Purpose:** Confirm broker access and derive the two wildcard subscriptions.
# **Execution:** Connect and display discovery and capability filters.
# **Expected result:** The broker accepts the connection and both filters are shown.

# %%
from examples.scripts.lab04_retained_metadata.step_01_connect_topics import run as step_01
run_notebook(lambda: step_01(config, base_topic, discovery_prefix))

# %% [markdown]
# ## Step 02: Read and validate retained metadata
# **Purpose:** Inspect discovery state topics and machine-readable read/write contracts.
# **Execution:** Subscribe to both filters and parse retained JSON.
# **Expected result:** Discovery and capability messages contain their blueprint-defined fields.

# %%
from examples.scripts.lab04_retained_metadata.step_02_read_validate import run as step_02
run_notebook(lambda: step_02(config, base_topic, discovery_prefix, seconds))
