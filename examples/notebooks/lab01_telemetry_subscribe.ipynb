# %% [markdown]
# # Lab 01: Subscribe to Telemetry
# Run from top to bottom. Broker failures are reported as skipped steps, without a traceback.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'examples').is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from examples.scripts.lab_common import BrokerConfig, run_notebook
config = BrokerConfig('127.0.0.1', 1883)
base_topic = 'homeassistant'
seconds = 10.0

# %% [markdown]
# ## Step 01: Connect to the broker
# **Purpose:** Confirm that the configured MQTT endpoint is reachable.
# **Execution:** Open an MQTT connection to `127.0.0.1:1883`.
# **Expected result:** The broker accepts the connection.

# %%
from examples.scripts.lab01_telemetry_subscribe.step_01_connect import run as step_01
run_notebook(lambda: step_01(config))

# %% [markdown]
# ## Step 02: Subscribe and validate telemetry
# **Purpose:** Read per-domain telemetry and distinguish event updates from heartbeat snapshots.
# **Execution:** Subscribe to `{base}/telemetry/#` and validate each per-domain JSON payload.
# **Expected result:** Envelope and record fields are complete, and `sample_type` matches `trigger_reason`.

# %%
from examples.scripts.lab01_telemetry_subscribe.step_02_subscribe_validate import run as step_02
run_notebook(lambda: step_02(config, base_topic, seconds))
