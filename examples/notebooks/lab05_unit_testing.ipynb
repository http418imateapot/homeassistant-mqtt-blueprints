# %% [markdown]
# # Lab 05: Unit Testing with pytest
# This notebook invokes the real tests under `tests/`; it does not duplicate their implementation.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'tests').is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

# %% [markdown]
# ## Step 01: Find Arrange, Act, Assert
# **Purpose:** Identify well-named tests before running them.
# **Execution:** Collect `tests/` and inspect the validator test's Arrange/Act/Assert shape.
# **Expected result:** Pytest lists validator and contract test IDs.

# %%
from examples.scripts.lab05_unit_testing.step_01_arrange_act_assert import run as step_01
step_01()

# %% [markdown]
# ## Step 02: Run the unit test suite
# **Purpose:** Execute all tests under `tests/`.
# **Execution:** Run `python -m pytest tests -q`.
# **Expected result:** The summary reports all tests passed.

# %%
from examples.scripts.lab05_unit_testing.step_02_run_suite import run as step_02
step_02()

# %% [markdown]
# ## Step 03: Run one parameterized case
# **Purpose:** Select a single case by pytest node ID.
# **Execution:** Run only the uploader parameter of the parallel-mode test.
# **Expected result:** Exactly one test passes.

# %%
from examples.scripts.lab05_unit_testing.step_03_run_single_param import run as step_03
step_03()

# %% [markdown]
# ## Step 04: Read a pytest failure
# **Purpose:** Interpret an assertion diff and short failure summary.
# **Execution:** Run an isolated temporary test with an intentional mode mismatch.
# **Expected result:** Pytest exits 1 for the demo; the lab recognizes that expected failure and continues.

# %%
from examples.scripts.lab05_unit_testing.step_04_read_failure import run as step_04
step_04()
